# %%
https://github.com/hamdanraja/Artificial-Neural-Network/tree/main

# %%
import pandas as pd
import numpy as np
import torch 
from torch.utils.data import TensorDataset, DataLoader


df=pd.read_csv(r"C:\Users\DELL\OneDrive\Desktop\HAMDAN NOTES\ANN\winequality-red.csv", delimiter=';')


x = df.drop("quality",axis=1).values
y = df["quality"].values

x_tensor=torch.tensor(x)
y_tensor=torch.tensor(y)

x_tensor.shape, y_tensor.shape
# Out:
# (torch.Size([1599, 11]), torch.Size([1599]))

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
# Step 2: Split features (x) and target (y)
x = df.drop(columns=['quality'])  # Replace 'quality' with your actual target column
y = df['quality']

# Step 3: Convert categorical variables in 'x' using one-hot encoding (if any)
x = pd.get_dummies(x, drop_first=True)

# Step 4: Convert both x and y to NumPy arrays and then to PyTorch tensors
x_tensor = torch.tensor(x.values, dtype=torch.float32)  # Convert x to a float32 tensor
y_tensor = torch.tensor(y.values, dtype=torch.float32)  # Convert y to a float32 tensor (ensure y is float if it's regression)

# Print to check if everything is converted properly
print("X Tensor Shape:", x_tensor.shape)
print("Y Tensor Shape:", y_tensor.shape)
# Out:
# X Tensor Shape: torch.Size([1599, 11])
# Y Tensor Shape: torch.Size([1599])

# %%
import torch
from torch.utils.data import DataLoader, TensorDataset

# Step 1: Create a TensorDataset
dataset = TensorDataset(x_tensor, y_tensor)

# Step 2: Create a DataLoader
data_loader = DataLoader(dataset, batch_size=32, shuffle=True)

# Step 3: Iterate through one batch of data
for batch_x, batch_y in data_loader:
    print("Batch X (features):", batch_x)
    print("Batch Y (targets):", batch_y)
    break  # Break after first batch to only print the first batch
# Out:
# Batch X (features): tensor([[5.6000e+00, 6.6000e-01, 0.0000e+00, 2.2000e+00, 8.7000e-02, 3.0000e+00,
#          1.1000e+01, 9.9378e-01, 3.7100e+00, 6.3000e-01, 1.2800e+01],
#         [8.3000e+00, 6.6000e-01, 1.5000e-01, 1.9000e+00, 7.9000e-02, 1.7000e+01,
#          4.2000e+01, 9.9720e-01, 3.3100e+00, 5.4000e-01, 9.6000e+00],
#         [1.0500e+01, 4.3000e-01, 3.5000e-01, 3.3000e+00, 9.2000e-02, 2.4000e+01,
#          7.0000e+01, 9.9798e-01, 3.2100e+00, 6.9000e-01, 1.0500e+01],
#         [9.2000e+00, 9.2000e-01, 2.4000e-01, 2.6000e+00, 8.7000e-02, 1.2000e+01,
#          9.3000e+01, 9.9980e-01, 3.4800e+00, 5.4000e-01, 9.8000e+00],
#         [6.8000e+00, 6.4000e-01, 1.0000e-01, 2.1000e+00, 8.5000e-02, 1.8000e+01,
#          1.0100e+02, 9.9560e-01, 3.3400e+00, 5.2000e-01, 1.0200e+01],
#         [7.1000e+00, 4.3000e-01, 4.2000e-01, 5.5000e+00, 7.1000e-02, 2.8000e+01,
#          1.2800e+02, 9.9730e-01, 3.4200e+00, 7.1000e-01, 1.0500e+01],
# ...
